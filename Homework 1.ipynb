# %%
import pandas as pd
train_df = pd.read_csv(r"C:\Users\Preston Overson\Documents\Python Scripts\Data\FIFA_PLAYER_DATA.csv")

# %%
train_df.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
train_df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
train_df['Nationality'].value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
# Brazil                   827
# Italy                    702
# Colombia                 618
# Japan                    478
# Netherlands              453
# Sweden                   397
# China PR                 392
# Chile                    391
# Republic of Ireland      368
# Mexico                   366
# United States            353
# Poland                   350
# Norway                   341
# Saudi Arabia             340
# Denmark                  336
# Korea Republic           335
# Portugal                 322
# Turkey                   303
# Austria                  298
# Scotland                 286
# Belgium                  260
# Australia                236
# Switzerland              220
# Uruguay                  149
# Senegal                  130
#                         ...
# Philippines                2
# ...

# %%
import seaborn as sns
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
sns.set(style='ticks', palette='Set2')
# shows graphs in notebook
# %matplotlib inline

# %%
weight = train_df['Weight'].apply(str).str[:-3]

# %%
weight = pd.to_numeric(weight)
weight
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
# 5        163.0
# 6        146.0
# 7        190.0
# 8        181.0
# 9        192.0
# 10       176.0
# 11       168.0
# 12       172.0
# 13       148.0
# 14       159.0
# 15       165.0
# 16       196.0
# 17       161.0
# 18       187.0
# 19       212.0
# 20       168.0
# 21       170.0
# 22       203.0
# 23       154.0
# 24       187.0
# 25       161.0
# 26       157.0
# 27       185.0
# 28       172.0
# 29       130.0
#          ...
# 18177    163.0
# 18178    176.0
# 18179    163.0
# 18180    172.0
# 18181    134.0
# 18182    165.0
# 18183    190.0
# 18184    179.0
# 18185    159.0
# 18186    174.0
# 18187    161.0
# 18188    148.0
# 18189    165.0
# 18190    176.0
# 18191    168.0
# 18192    165.0
# 18193    146.0
# 18194    187.0
# 18195    141.0
# 18196    146.0
# 18197    141.0
# 18198    154.0
# 18199    150.0
# 18200    157.0
# 18201    168.0
# 18202    134.0
# 18203    170.0
# ...

# %%
train_df['Weight'] = weight

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
import seaborn as sns
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
sns.set(style='ticks', palette='Set2')
# shows graphs in notebook
# %matplotlib inline

sns.lmplot(x="Weight", y="Height", data=train_df)
# Out:
# C:\Users\Preston Overson\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="Overall", y="Potential", data=train_df)

# %%
sns.barplot(train_df.Nationality, train_df.Overall)

# %%
import json
import pandas as pd
with open(r"\Users\Preston Overson\Documents\Python Scripts\Data\airlines.JSON") as f:
    air_data = json.load(f)

# %%
from pandas.io.json import json_normalize
air_df = json_normalize(air_data)
air_df.head(5)
# Out:
#   airport.code                                       airport.name  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1          BOS                    Boston, MA: Logan International
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3          CLT     Charlotte, NC: Charlotte Douglas International
# 4          DCA  Washington, DC: Ronald Reagan Washington National
#
#   carrier.code            carrier.name  statistics.# of delays.carrier  \
# 0           AA  American Airlines Inc.                              34
# 1           AA  American Airlines Inc.                              69
# 2           AA  American Airlines Inc.                              18
# 3           AA  American Airlines Inc.                              17
# 4           AA  American Airlines Inc.                              43
#
#    statistics.# of delays.late aircraft  \
# 0                                    18
# 1                                    46
# ...

# %%
air_df.describe()
# Out:
#        statistics.# of delays.carrier  statistics.# of delays.late aircraft  \
# count                    54013.000000                          54013.000000
# mean                        46.895747                             64.396719
# std                         82.224183                            141.040411
# min                         -1.000000                             -1.000000
# 25%                          8.000000                              5.000000
# 50%                         20.000000                             16.000000
# 75%                         47.000000                             49.000000
# max                       1792.000000                           1885.000000
#
#        statistics.# of delays.national aviation system  \
# count                                     54013.000000
# mean                                         77.903283
# std                                         175.675007
# min                                          -1.000000
# ...

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54013 entries, 0 to 54012
# Data columns (total 23 columns):
# airport.code                                           54013 non-null object
# airport.name                                           54013 non-null object
# carrier.code                                           54013 non-null object
# carrier.name                                           54013 non-null object
# statistics.# of delays.carrier                         54013 non-null int64
# statistics.# of delays.late aircraft                   54013 non-null int64
# statistics.# of delays.national aviation system        54013 non-null int64
# statistics.# of delays.security                        54013 non-null int64
# statistics.# of delays.weather                         54013 non-null int64
# statistics.flights.cancelled                           54013 non-null int64
# statistics.flights.delayed                             54013 non-null int64
# ...

# %%
atl_df =  air_df['airport.code']=='ATL'

# %%
atl_df.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: airport.code, dtype: bool

# %%
atl_df = air_df[atl_df]

# %%
atl_dl_df =  atl_df['carrier.code']=='DL'
atl_dl_df = atl_df[atl_dl_df]
atl_dl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 95 to 53831
# Data columns (total 23 columns):
# airport.code                                           152 non-null object
# airport.name                                           152 non-null object
# carrier.code                                           152 non-null object
# carrier.name                                           152 non-null object
# statistics.# of delays.carrier                         152 non-null int64
# statistics.# of delays.late aircraft                   152 non-null int64
# statistics.# of delays.national aviation system        152 non-null int64
# statistics.# of delays.security                        152 non-null int64
# statistics.# of delays.weather                         152 non-null int64
# statistics.flights.cancelled                           152 non-null int64
# statistics.flights.delayed                             152 non-null int64
# ...

# %%
import seaborn as sns
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
sns.set(style='ticks', palette='Set2')
# shows graphs in notebook
# %matplotlib inline


x = atl_dl_df['time.label']
y = atl_dl_df['statistics.# of delays.weather']
fig = sns.lineplot(x, y)
fig.set(xlabel='Time', ylabel='# Delays Due to Weather')
plt.show()

# %%
atl_dl_df_2008 = atl_dl_df['time.year'] == 2008
atl_dl_df_2008 = atl_dl_df[atl_dl_df_2008]
atl_dl_df_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 21382 to 25725
# Data columns (total 23 columns):
# airport.code                                           12 non-null object
# airport.name                                           12 non-null object
# carrier.code                                           12 non-null object
# carrier.name                                           12 non-null object
# statistics.# of delays.carrier                         12 non-null int64
# statistics.# of delays.late aircraft                   12 non-null int64
# statistics.# of delays.national aviation system        12 non-null int64
# statistics.# of delays.security                        12 non-null int64
# statistics.# of delays.weather                         12 non-null int64
# statistics.flights.cancelled                           12 non-null int64
# statistics.flights.delayed                             12 non-null int64
# ...

# %%
#Plotting delas for delta in 2008

x = atl_dl_df_2008['time.month']
y = atl_dl_df_2008['statistics.minutes delayed.carrier']
fig = sns.lineplot(x, y)
fig.set(xlabel='Month', ylabel='Delta Delays (minutes)')
plt.show()

# %%
import pandas as pd
import requests
import json

# %%
url = "https://api.carbonintensity.org.uk/intensity/2018-08-25T15:30Z/2018-09-20T17:00Z"
carbon_data = requests.get(url).text
carbon_dict = json.loads(requests.get(url).text)

# %%
carbon_dict.keys()
# Out:
# dict_keys(['data'])

# %%
carbon_dict
# Out:
# {'data': [{'from': '2018-08-25T15:00Z',
#    'to': '2018-08-25T15:30Z',
#    'intensity': {'forecast': 158, 'actual': 198, 'index': 'moderate'}},
#   {'from': '2018-08-25T15:30Z',
#    'to': '2018-08-25T16:00Z',
#    'intensity': {'forecast': 171, 'actual': 218, 'index': 'moderate'}},
#   {'from': '2018-08-25T16:00Z',
#    'to': '2018-08-25T16:30Z',
#    'intensity': {'forecast': 186, 'actual': 237, 'index': 'moderate'}},
#   {'from': '2018-08-25T16:30Z',
#    'to': '2018-08-25T17:00Z',
#    'intensity': {'forecast': 205, 'actual': 244, 'index': 'moderate'}},
#   {'from': '2018-08-25T17:00Z',
#    'to': '2018-08-25T17:30Z',
#    'intensity': {'forecast': 218, 'actual': 250, 'index': 'moderate'}},
#   {'from': '2018-08-25T17:30Z',
#    'to': '2018-08-25T18:00Z',
#    'intensity': {'forecast': 229, 'actual': 262, 'index': 'moderate'}},
#   {'from': '2018-08-25T18:00Z',
#    'to': '2018-08-25T18:30Z',
#    'intensity': {'forecast': 238, 'actual': 269, 'index': 'moderate'}},
# ...
